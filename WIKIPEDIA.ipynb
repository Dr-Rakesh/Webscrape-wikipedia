# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
response = requests.get('https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications')

# %%
response.status_code
# Out:
# 200

# %%
page_contents = response.text

# %%
with open ('marvel.html', 'w', encoding='utf-8') as f:
    f.write(page_contents)

# %%
doc = bs(page_contents, 'html.parser')

# %%
table_tags = doc.find_all('table',{'class':'wikitable sortable'})

# %%
tt=table_tags[0]
tt
# Out:
# <table class="wikitable sortable"><tbody><tr><th>Year
# </th>
# <th>Title
# </th>
# <th>Production studio(s)
# </th>
# <th>Notes
# </th></tr><tr><td>1986
# </td>
# <td><i><a href="/wiki/Howard_the_Duck_(film)" title="Howard the Duck (film)">Howard the Duck</a></i>
# </td>
# <td><a href="/wiki/Universal_Pictures" title="Universal Pictures">Universal Pictures</a>
# </td>
# <td>Co-produced by <a href="/wiki/Lucasfilm" title="Lucasfilm">Lucasfilm</a>
# </td></tr><tr><td>1998
# </td>
# <td><i><a href="/wiki/Blade_(film)" title="Blade (film)">Blade</a></i>
# </td>
# <td><a href="/wiki/New_Line_Cinema" title="New Line Cinema">New Line Cinema</a>
# </td>
# <td rowspan="3">
# </td></tr><tr><td>2000
# </td>
# <td><i><a href="/wiki/X-Men_(film)" title="X-Men (film)">X-Men</a></i>
# </td>
# <td><a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
# </td></tr><tr><td rowspan="2">2002
# </td>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import dateutil

# %%
assert response.status_code==200

# %%
src = response.content
doc = BeautifulSoup(src, 'lxml')

# %%
table=doc.find('table')

# %%
assert table.find("th").get_text()

# %%
rows = table.find_all("tr")  # Note: this works because find_all is resursive by default

# %%
rows
# Out:
# [<tr><th>Year
#  </th>
#  <th>Title
#  </th>
#  <th>Production studio(s)
#  </th>
#  <th>Notes
#  </th></tr>,
#  <tr><td>1986
#  </td>
#  <td><i><a href="/wiki/Howard_the_Duck_(film)" title="Howard the Duck (film)">Howard the Duck</a></i>
#  </td>
#  <td><a href="/wiki/Universal_Pictures" title="Universal Pictures">Universal Pictures</a>
#  </td>
#  <td>Co-produced by <a href="/wiki/Lucasfilm" title="Lucasfilm">Lucasfilm</a>
#  </td></tr>,
#  <tr><td>1998
#  </td>
#  <td><i><a href="/wiki/Blade_(film)" title="Blade (film)">Blade</a></i>
#  </td>
#  <td><a href="/wiki/New_Line_Cinema" title="New Line Cinema">New Line Cinema</a>
#  </td>
#  <td rowspan="3">
#  </td></tr>,
#  <tr><td>2000
#  </td>
#  <td><i><a href="/wiki/X-Men_(film)" title="X-Men (film)">X-Men</a></i>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
#  </td></tr>,
#  <tr><td rowspan="2">2002
#  </td>
# ...

# %%
for row in rows:
    cells = row.find_all(["td", "th"])
    
    cells_text = [cell.get_text(strip=True) for cell in cells]
    (Year, Title, Production_studio, Notes) = cells_text
    
    # Clean population using a regular expression str("1,404,890,600") -> int(1404890600)
    Year = int(re.sub(Year))   
    
    # Clean country name
    Title = re.findall(Title)[0]
    
    # Convert percentage to floats
    percentage = float(re.findall(Production_studio[0]) 
    
  
    
    print(f"{Year}, {Title}, {Production_studio}, {Notes}")
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_13788/186662498.py", line 18
#     print(f"{Year}, {Title}, {Production_studio}, {Notes}")
#     ^
# SyntaxError: invalid syntax

# %%
response = requests.get('https://en.m.wikipedia.org/wiki/Doctor_Strange_in_the_Multiverse_of_Madness')

# %%
response.status_code
# Out:
# 200

# %%
page_contents = response.text

# %%
with open ('dr_strange.html', 'w', encoding='utf-8') as f:
    f.write(page_contents)

# %%
doc = bs(page_contents, 'html.parser')

# %%
t=doc.prettify()
print(t)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Doctor Strange in the Multiverse of Madness - Wikipedia
#   </title>
#   <script>
# ...

# %%
info=doc.find(class_='infobox vevent')
irows= info.find_all('tr')
irows
# Out:
# [<tr><th class="infobox-above summary" colspan="2" style="font-size: 125%; font-style: italic;">Doctor Strange in the<br/><span class="nowrap">Multiverse of Madness</span></th></tr>,
#  <tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg"><img alt="Doctor Strange in the Multiverse of Madness poster.jpg" class="thumbborder" data-file-height="384" data-file-width="259" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/thumb/1/17/Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg/220px-Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg" width="220"/></a><div class="infobox-caption">Theatrical release poster</div></td></tr>,
#  <tr><th class="infobox-label" scope="row" style="white-space: nowrap; padding-right: 0.65em;">Directed by</th><td class="infobox-data"><a href="/wiki/Sam_Raimi" title="Sam Raimi">Sam Raimi</a></td></tr>,
# ...

# %%
throws=info.find_all('th')
throws[1].text
# Out:
# 'Directed by'

# %%
tdrows=info.find_all('td')
tdrows[1].text
# Out:
# 'Sam Raimi'

# %%
def get_value(row_data):
    if row_data.find('li'):
        return [li.get_text('',strip=True).replace('\xa0','') for li in row_data.find_all('li')]
    else:
        return row_data.get_text().replace('\xa0','')

movie = {}

for index, row in enumerate(irows):
    if index == 0:
        movie['title'] = row.find('th').get_text('',strip=True)
    elif  index == 1:
        continue
    else:
        key = row.find('th').get_text('',strip=True)
        value = get_value(row.find('td'))
        movie[key] = value

movie
# Out:
# {'title': 'Doctor Strange in theMultiverse of Madness',
#  'Directed by': 'Sam Raimi',
#  'Written by': 'Michael Waldron',
#  'Based on': 'Marvel Comics',
#  'Produced by': 'Kevin Feige',
#  'Starring': ['Benedict Cumberbatch',
#   'Elizabeth Olsen',
#   'Chiwetel Ejiofor',
#   'Benedict Wong',
#   'Xochitl Gomez',
#   'Michael Stuhlbarg',
#   'Rachel McAdams'],
#  'Cinematography': 'John Mathieson',
#  'Edited by': ['Bob Murawski', 'Tia Nolan'],
#  'Music by': 'Danny Elfman',
#  'Productioncompany': 'Marvel Studios',
#  'Distributed by': 'Walt Disney StudiosMotion Pictures',
#  'Release dates': ['May2,2022(2022-05-02)(Dolby Theatre)',
#   'May6,2022(2022-05-06)(United States)'],
#  'Running time': '126 minutes[1]',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$200 million[2]',
#  'Box office': '$930.2 million[3][4]'}

# %%
movie = {}
for index, row in enumerate(irows):
    if index == 0:
        movie = row.find('th').get_text('',strip=True)

movie
# Out:
# 'Doctor Strange in theMultiverse of Madness'

# %%
url='https://en.m.wikipedia.org/wiki/Daredevil_(film)'

# %%
response = requests.get(url)
response.status_code == 200
# Out:
# True

# %%
page_contents = response.text
with open ('s.html', 'w', encoding='utf-8') as f:
    f.write(page_contents)
doc = bs(page_contents, 'html.parser')

# %%
info=doc.find(class_='infobox vevent')
irows= info.find_all('tr')

# %%
t = url[32:]
t
# Out:
# 'Daredevil_(film)'

# %%
import pickle


def save_data(name, data):
    with open (name,'wb') as f:
        pickle.dump(data,f)

# %%
import pickle

def load_data(name):
    with open (name, 'rb') as f:
        return pickle.load(f)

# %%
save_data('movie1.pickle',movie)

# %%
a = load_data('movie1.pickle')

# %%
a
# Out:
# {'title': 'Doctor Strange in theMultiverse of Madness',
#  'Directed by': 'Sam Raimi',
#  'Written by': 'Michael Waldron',
#  'Based on': 'Marvel Comics',
#  'Produced by': 'Kevin Feige',
#  'Starring': ['Benedict Cumberbatch',
#   'Elizabeth Olsen',
#   'Chiwetel Ejiofor',
#   'Benedict Wong',
#   'Xochitl Gomez',
#   'Michael Stuhlbarg',
#   'Rachel McAdams'],
#  'Cinematography': 'John Mathieson',
#  'Edited by': ['Bob Murawski', 'Tia Nolan'],
#  'Music by': 'Danny Elfman',
#  'Productioncompany': 'Marvel Studios',
#  'Distributed by': 'Walt Disney StudiosMotion Pictures',
#  'Release dates': ['May2,2022(2022-05-02)(Dolby Theatre)',
#   'May6,2022(2022-05-06)(United States)'],
#  'Running time': '126 minutes[1]',
#  'Country': 'United States',
#  'Language': 'English',
#  'Budget': '$200 million[2]',
#  'Box office': '$930.2 million[3][4]'}

# %%
import pandas as pd
dt = pd.DataFrame(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10732/1093715800.py in <module>
#       1 import pandas as pd
# ----> 2 dt = pd.DataFrame(a)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
# ...

# %%
dt
# Out:
# 32

# %%
response = requests.get('https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications')

# %%
response.status_code
# Out:
# 200

# %%
page_contents = response.text

# %%
with open ('marvel.html', 'w', encoding='utf-8') as f:
    f.write(page_contents)

# %%
docx = bs(page_contents, 'html.parser')

# %%
page_contents[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of films based on Marvel Comics publications - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"c13d467b-70ae-4662-a539-bc4e1ba40cf2","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_films_based_on_Marvel_Comics_publications","wgTitle":"List of films based on Marvel Comics publications","wgCurRevisionId":1092252824,"wgRevisionId":1092252824,"wgArticleId":878659,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgPageContentLanguage":"en","wgPageContentModel":"wiki
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import dateutil

# %%
table_tags = docx.find_all('table')
table_tags
# Out:
# [<table class="wikitable sortable"><tbody><tr><th>Year
#  </th>
#  <th>Title
#  </th>
#  <th>Production studio(s)
#  </th>
#  <th>Notes
#  </th></tr><tr><td>1986
#  </td>
#  <td><i><a href="/wiki/Howard_the_Duck_(film)" title="Howard the Duck (film)">Howard the Duck</a></i>
#  </td>
#  <td><a href="/wiki/Universal_Pictures" title="Universal Pictures">Universal Pictures</a>
#  </td>
#  <td>Co-produced by <a href="/wiki/Lucasfilm" title="Lucasfilm">Lucasfilm</a>
#  </td></tr><tr><td>1998
#  </td>
#  <td><i><a href="/wiki/Blade_(film)" title="Blade (film)">Blade</a></i>
#  </td>
#  <td><a href="/wiki/New_Line_Cinema" title="New Line Cinema">New Line Cinema</a>
#  </td>
#  <td rowspan="3">
#  </td></tr><tr><td>2000
#  </td>
#  <td><i><a href="/wiki/X-Men_(film)" title="X-Men (film)">X-Men</a></i>
#  </td>
#  <td><a class="mw-redirect" href="/wiki/20th_Century_Fox" title="20th Century Fox">20th Century Fox</a>
#  </td></tr><tr><td rowspan="2">2002
#  </td>
# ...

# %%
movie = docx.find_all('table',{'class':'wikitable sortable'})
movie[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10732/3971545499.py in <module>
# ----> 1 movie = docx.find_all('table',{'class':'wikitable sortable'})
#       2 movie[0:10]
#
# NameError: name 'docx' is not defined

# %%
## new table start

# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import dateutil

# %%
url = 'https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications'

# %%
r= requests.get(url)
soup = bs(r.content)

contents = soup.prettify()
print(contents)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of films based on Marvel Comics publications - Wikipedia
#   </title>
#   <script>
# ...

# %%
movies = soup.select('.wikitable.sortable i')

# %%
movies[0:10]
# Out:
# [<i><a href="/wiki/Howard_the_Duck_(film)" title="Howard the Duck (film)">Howard the Duck</a></i>,
#  <i><a href="/wiki/Blade_(film)" title="Blade (film)">Blade</a></i>,
#  <i><a href="/wiki/X-Men_(film)" title="X-Men (film)">X-Men</a></i>,
#  <i><a href="/wiki/Blade_II" title="Blade II">Blade II</a></i>,
#  <i><a href="/wiki/Spider-Man_(2002_film)" title="Spider-Man (2002 film)">Spider-Man</a></i>,
#  <i><a href="/wiki/Daredevil_(film)" title="Daredevil (film)">Daredevil</a></i>,
#  <i><a href="/wiki/X2_(film)" title="X2 (film)">X2</a></i>,
#  <i><a href="/wiki/Hulk_(film)" title="Hulk (film)">Hulk</a></i>,
#  <i><a href="/wiki/The_Punisher_(2004_film)" title="The Punisher (2004 film)">The Punisher</a></i>,
#  <i><a href="/wiki/Spider-Man_2" title="Spider-Man 2">Spider-Man 2</a></i>]

# %%
def get_value(row_data):
    if row_data.find('li'):
        return [li.get_text('',strip=True).replace('\xa0','') for li in row_data.find_all('li')]
    else:
        return row_data.get_text().replace('\xa0','')

def info (url):
    r= requests.get(url)
    soup = bs(r.content)
    info_box = soup.find(class_='infobox vevent')
    infobox_rows = info_box.find_all('tr')
    
    movie = {}

    for index, row in enumerate(irows):
        if index == 0:
            movie['title'] = row.find('th').get_text('',strip=True)
        elif  index == 1:
            continue
        else:
            key = row.find('th').get_text('',strip=True)
            value = get_value(row.find('td'))
            movie[key] = value
    return movies

# %%
url1 = 'https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications'

# %%
r = requests.get('url1')
soup = bs(r.content)
movies = soup.select('.wikitable.sortable i')
for index, row in enumerate(irows):
    if index == 0:
        movie['title'] = row.find('th').get_text('',strip=True)
    elif  index == 1:
        continue

# %%
url2 = 'https://en.m.wikipedia.org/wiki/Doctor_Strange_in_the_Multiverse_of_Madness'

# %%
# !pip install urllib2 --quite --upgrade
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --quite

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get(url2)
response.status_code == 200
# Out:
# True

# %%
page_contents = response.text

# %%
with open ('dr_strange.html', 'w', encoding='utf-8') as f:
    f.write(page_contents)

# %%
soup = BeautifulSoup(page_contents, 'html.parser')

# %%
page_contents[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Doctor Strange in the Multiverse of Madness - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"c0398286-570a-4f71-8087-8640920080ed","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Doctor_Strange_in_the_Multiverse_of_Madness","wgTitle":"Doctor Strange in the Multiverse of Madness","wgCurRevisionId":1092787725,"wgRevisionId":1092787725,"wgArticleId":59353603,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevan
# ...

# %%
movie = soup.find_all('table',{'class':'infobox vevent'})
movie
# Out:
# [<table class="infobox vevent"><tbody><tr><th class="infobox-above summary" colspan="2" style="font-size: 125%; font-style: italic;">Doctor Strange in the<br/><span class="nowrap">Multiverse of Madness</span></th></tr><tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg"><img alt="Doctor Strange in the Multiverse of Madness poster.jpg" class="thumbborder" data-file-height="384" data-file-width="259" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/thumb/1/17/Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg/220px-Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg" width="220"/></a><div class="infobox-caption">Theatrical release poster</div></td></tr><tr><th class="infobox-label" scope="row" style="white-space: nowrap; padding-right: 0.65em;">Directed by</th><td class="infobox-data"><a href="/wiki/Sam_Raimi" title="Sam Raimi">Sam Raimi</a></td></tr><tr><th class="infobox-label"
# ...

# %%
info=soup.find(class_='infobox vevent')
irows= info.find_all('tr')
irows
# Out:
# [<tr><th class="infobox-above summary" colspan="2" style="font-size: 125%; font-style: italic;">Doctor Strange in the<br/><span class="nowrap">Multiverse of Madness</span></th></tr>,
#  <tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg"><img alt="Doctor Strange in the Multiverse of Madness poster.jpg" class="thumbborder" data-file-height="384" data-file-width="259" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/thumb/1/17/Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg/220px-Doctor_Strange_in_the_Multiverse_of_Madness_poster.jpg" width="220"/></a><div class="infobox-caption">Theatrical release poster</div></td></tr>,
#  <tr><th class="infobox-label" scope="row" style="white-space: nowrap; padding-right: 0.65em;">Directed by</th><td class="infobox-data"><a href="/wiki/Sam_Raimi" title="Sam Raimi">Sam Raimi</a></td></tr>,
# ...

# %%
def get_value(row_data):
    if row_data.find('li'):
        return [li.get_text('',strip=True).replace('\xa0','') for li in row_data.find_all('li')]
    else:
        return row_data.get_text().replace('\xa0','')

movie = {}
keys = []
for index, row in enumerate(irows):
    if index == 0:
        movie['title'] = row.find('th').get_text('',strip=True)
    elif  index == 1:
        continue
    else:
        key = row.find('th').get_text('',strip=True)
        value = get_value(row.find('td'))
        movie[key] = value
        keys = key
        print (key)
        keys.append(key)
# Out:
# Directed by
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10732/3371496276.py in <module>
#      18         keys = key
#      19         print (key)
# ---> 20         keys.append(key)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
t
# Out:
# [None]

# %%
keys = []

for keys in movie:
    info.find('td').get_text('',strip=True)
    
keys
# Out:
# 'Box office'

# %%
value = []

for value in movie:
    soup.find('title').get_text('',strip=True)
    
print(value)
# Out:
# Box office

# %%
movie_detail
# Out:
# {'Title': None, 'Description': None}

# %%
pf
# Out:
#        Titles           Description
# 0  Box office  $915.9 million[3][4]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10732/2227814469.py in <module>
# ----> 1 movie_detail[0:100]
#
# TypeError: unhashable type: 'slice'

# %%
pf = pd.DataFrame(movie_detail)
pf
# Out:
#           Titles  Description
# 0  [Directed by]  [Sam Raimi]

# %%
6/18/2022
# Out:
# 0.00016485328058028355

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url='https://en.m.wikipedia.org/wiki/Thor:_Love_and_Thunder'

# %%
response = requests.get(url)
response.status_code == 200
# Out:
# True

# %%
soup = bs(response.content)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Thor: Love and Thunder - Wikipedia</title>
# ...

# %%
info=soup.find(class_='infobox vevent')
irows= info.find_all('tr')
irows
# Out:
# [<tr><th class="infobox-above summary" colspan="2" style="font-size: 125%; font-style: italic;">Thor: Love and Thunder</th></tr>,
#  <tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Thor_Love_and_Thunder_poster.jpeg"><img alt="Thor Love and Thunder poster.jpeg" class="thumbborder" data-file-height="385" data-file-width="260" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/thumb/8/88/Thor_Love_and_Thunder_poster.jpeg/220px-Thor_Love_and_Thunder_poster.jpeg" width="220"/></a><div class="infobox-caption">Theatrical release poster</div></td></tr>,
#  <tr><th class="infobox-label" scope="row" style="white-space: nowrap; padding-right: 0.65em;">Directed by</th><td class="infobox-data"><a href="/wiki/Taika_Waititi" title="Taika Waititi">Taika Waititi</a></td></tr>,
#  <tr><th class="infobox-label" scope="row" style="white-space: nowrap; padding-right: 0.65em;">Written by</th><td class="infobox-data"><div class="plainlist">
# ...

# %%
def get_value(row_data):
    if row_data.find('li'):
        return [li.get_text('',strip=True).replace('\xa0','') for li in row_data.find_all('li')]
    elif row_data.find('br'):
        return [text for text in row_data.stripped_strings]
    else:
        return row_data.get_text('',strip=True).replace('\xa0','')

def clean_tags(soup):
    for tag in soup.find_all('sup', 'span'):
        tag.decompose()
        
movie = {}
    
for index, row in enumerate(irows):
    if index == 0:
        movie['title'] = row.find('th').get_text('',strip=True)
    else:
        header = row.find('th')
        if header:
            key = row.find('th').get_text('',strip=True)
            value = get_value(row.find('td'))
            movie[key] = value

# %%
movie
# Out:
# {'title': 'Thor: Love and Thunder',
#  'Directed by': 'Taika Waititi',
#  'Written by': ['Taika Waititi[N 1]', 'Jennifer Kaytin Robinson'],
#  'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#  'Produced by': ['Kevin Feige', 'Brad Winderbaum'],
#  'Starring': ['Chris Hemsworth',
#   'Christian Bale',
#   'Tessa Thompson',
#   'Jaimie Alexander',
#   'Taika Waititi',
#   'Russell Crowe',
#   'Natalie Portman'],
#  'Cinematography': 'Barry Idoine',
#  'Edited by': ['Matthew Schmidt',
#   'Peter S. Elliot',
#   'Tim Roche',
#   'Jennifer Vecchiarello'],
#  'Music by': 'Michael Giacchino',
#  'Productioncompany': 'Marvel Studios',
#  'Distributed by': ['Walt Disney Studios', 'Motion Pictures'],
#  'Release dates': ['June23,2022(2022-06-23)(Los Angeles)',
#   'July8,2022(2022-07-08)(United States)'],
#  'Country': 'United States',
#  'Language': 'English'}

# %%
import json
def save_data (title,data):
    with open (title,'w', encoding ='utf=8') as f:
        json.dump(data,f,ensure_ascii=False, indent=2)

# %%
import json
def load_data (title):
    with open (title, encoding ='utf=8') as f:
        return json.load (f)

# %%
save_data('thor',movie)

# %%
import pickle


def save_data(name, data):
    with open (name,'wb') as f:
        pickle.dump(data,f)

# %%
import pickle

def load_data(name):
    with open (name, 'rb') as f:
        return pickle.load(f)

# %%
save_data('movie.pickle',movie)

# %%
a = load_data('movie.pickle')

# %%
a
# Out:
# {'title': 'Thor: Love and Thunder',
#  'Directed by': 'Taika Waititi',
#  'Written by': ['Taika Waititi[N 1]', 'Jennifer Kaytin Robinson'],
#  'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#  'Produced by': ['Kevin Feige', 'Brad Winderbaum'],
#  'Starring': ['Chris Hemsworth',
#   'Christian Bale',
#   'Tessa Thompson',
#   'Jaimie Alexander',
#   'Taika Waititi',
#   'Russell Crowe',
#   'Natalie Portman'],
#  'Cinematography': 'Barry Idoine',
#  'Edited by': ['Matthew Schmidt',
#   'Peter S. Elliot',
#   'Tim Roche',
#   'Jennifer Vecchiarello'],
#  'Music by': 'Michael Giacchino',
#  'Productioncompany': 'Marvel Studios',
#  'Distributed by': ['Walt Disney Studios', 'Motion Pictures'],
#  'Release dates': ['June23,2022(2022-06-23)(Los Angeles)',
#   'July8,2022(2022-07-08)(United States)'],
#  'Country': 'United States',
#  'Language': 'English'}

# %%
movie1=[a.copy() for imovie in a]

# %% [markdown]
# movie1

# %%
movie1
# Out:
# [{'title': 'Thor: Love and Thunder',
#   'Directed by': 'Taika Waititi',
#   'Written by': ['Taika Waititi[N 1]', 'Jennifer Kaytin Robinson'],
#   'Based on': ['Stan Lee', 'Larry Lieber', 'Jack Kirby'],
#   'Produced by': ['Kevin Feige', 'Brad Winderbaum'],
#   'Starring': ['Chris Hemsworth',
#    'Christian Bale',
#    'Tessa Thompson',
#    'Jaimie Alexander',
#    'Taika Waititi',
#    'Russell Crowe',
#    'Natalie Portman'],
#   'Cinematography': 'Barry Idoine',
#   'Edited by': ['Matthew Schmidt',
#    'Peter S. Elliot',
#    'Tim Roche',
#    'Jennifer Vecchiarello'],
#   'Music by': 'Michael Giacchino',
#   'Productioncompany': 'Marvel Studios',
#   'Distributed by': ['Walt Disney Studios', 'Motion Pictures'],
#   'Release dates': ['June23,2022(2022-06-23)(Los Angeles)',
#    'July8,2022(2022-07-08)(United States)'],
#   'Country': 'United States',
#   'Language': 'English'},
#  {'title': 'Thor: Love and Thunder',
#   'Directed by': 'Taika Waititi',
# ...

# %%
save_data('thor.json',movie1)

# %%
import pandas as pd
dt = pd.DataFrame(movie1)

# %%
dt
# Out:
#                      title    Directed by  \
# 0   Thor: Love and Thunder  Taika Waititi
# 1   Thor: Love and Thunder  Taika Waititi
# 2   Thor: Love and Thunder  Taika Waititi
# 3   Thor: Love and Thunder  Taika Waititi
# 4   Thor: Love and Thunder  Taika Waititi
# 5   Thor: Love and Thunder  Taika Waititi
# 6   Thor: Love and Thunder  Taika Waititi
# 7   Thor: Love and Thunder  Taika Waititi
# 8   Thor: Love and Thunder  Taika Waititi
# 9   Thor: Love and Thunder  Taika Waititi
# 10  Thor: Love and Thunder  Taika Waititi
# 11  Thor: Love and Thunder  Taika Waititi
# 12  Thor: Love and Thunder  Taika Waititi
# 13  Thor: Love and Thunder  Taika Waititi
#
#                                         Written by  \
# 0   [Taika Waititi[N 1], Jennifer Kaytin Robinson]
# 1   [Taika Waititi[N 1], Jennifer Kaytin Robinson]
# 2   [Taika Waititi[N 1], Jennifer Kaytin Robinson]
# 3   [Taika Waititi[N 1], Jennifer Kaytin Robinson]
# 4   [Taika Waititi[N 1], Jennifer Kaytin Robinson]
# ...

# %%
dt.to_csv('thor.csv')

# %%
url1 = 'https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications'

# %%
r = requests.get(url1)
soup = bs(r.content)
movies = soup.select('.wikitable.sortable i')

# %%
def get_value(row_data):
    if row_data.find('li'):
        return [li.get_text('',strip=True).replace('\xa0','') for li in row_data.find_all('li')]
    else:
        return row_data.get_text('',strip=True).replace('\xa0','')

def clean_tags(soup):
    for tag in soup.find_all('sup'):
        tag.decompose()    
    
def get_info_box(url1):
    r = requests.get(url1)
    soup = bs(r.content)
    print (contents)
    info=soup.find(class_='infobox vevent')
    irows= info.find_all('tr')
    
    movie = {}


    for index, row in enumerate(irows):
        if index == 0:
            movie['title'] = row.find('th').get_text('',strip=True)
        elif  index == 1:
            continue
        else:
            key = row.find('th').get_text('',strip=True)
            value = get_value(row.find('td'))
            movie[key] = value
        return movie

# %%
pf = pd.DataFrame(movie_detail)
pf

# %%
url1 = 'https://en.m.wikipedia.org/wiki/List_of_films_based_on_Marvel_Comics_publications'

# %%
r = requests.get(url1)
soup = bs(r.content)
movies = soup.select('.wikitable.sortable i a')

base_path = 'https://en.wikipedia.org/'

movie_info_list = []
for index, imovie in enumerate(movies):
    if index == 10:
        break
    try:
        relative_path = imovie['href']
        full_path = base_path + relative_path
        title = imovie['title']
        
        movie_info_list.append(get_info_box(full_path))
        
    except Exception as e:
        print (imovie.get_text())
        print (e)
# Out:
# Howard the Duck
# name 'contents' is not defined
# Blade
# name 'contents' is not defined
# X-Men
# name 'contents' is not defined
# Blade II
# name 'contents' is not defined
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8912/2641476572.py in <module>
#      14         title = imovie['title']
#      15
# ---> 16         movie_info_list.append(get_info_box(full_path))
#      17
#      18     except Exception as e:
#
# ~\AppData\Local\Temp/ipykernel_8912/41391216.py in get_info_box(url1)
#       6
#       7 def get_info_box(url1):
# ----> 8     r = requests.get(url1)
#       9     soup = bs(r.content)
#      10     print (contents)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...

# %%
len(movie_info_list)
# Out:
# 0

# %%
import json
def save_data(title,data):
    with open
